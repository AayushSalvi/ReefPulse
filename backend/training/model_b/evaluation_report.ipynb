# %% [markdown]
# # ReefPulse Model B Evaluation Report
#
# This notebook should become the model card / demo artifact for the anomaly detector.

# %% [markdown]
# ## Expected artifacts
#
# - Anomaly score time series with the Blob highlighted
# - Per-feature reconstruction error for spike dates
# - Baseline vs VAE comparison
# - Threshold recommendation for alerting
