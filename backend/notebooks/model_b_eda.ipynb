# %% [markdown]
# # ReefPulse Model B EDA
#
# Use this notebook to understand what normal ocean conditions look like before training the anomaly detector.

# %% [markdown]
# ## Checklist
#
# - Plot temperature distributions by season
# - Check missing values and outliers
# - Inspect correlations between temperature, salinity, oxygen, and chlorophyll
# - Mark 2014-2016 as the Blob validation window

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# TODO: load the post-1993 CalCOFI dataset from S3 or a local parquet export
# df = pd.read_parquet('../training/model_b/artifacts/...')
df = pd.DataFrame()
